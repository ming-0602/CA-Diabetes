# %% [markdown]
# Diabetes Dataset
#
# The dataset is collected from the Iraqi society. The data consist of No. of Patient, Sugar Level Blood, Age, Gender, Creatinine ratio(Cr), Body Mass Index (BMI), Urea, Cholesterol (Chol), Fasting lipid profile, including total, LDL, VLDL, Triglycerides(TG) and HDL Cholesterol , HBA1C and Class of diabetes or non diabetes patient. The Objective of this study is to find the most potential characteristic of the diabeties. As World Health Organization show there are 422 million people wordwide which have diabeties and 1.5 million death are contributed by diabetes each year. As the study, it can show the effect of the characteristic of diabeties and improve the accurate approach to diagnosis the disease.
#
#
# What are the characteristic of diabeties?
#
# Diabeties have multiple characteristic that can be determine such as Gender, Age , Urea, Cholesterol, etc. To determine these factor, it able to find the most obvious characteristic to help improve the diagnosis of diabeties.

# %% [markdown]
# Data Understanding

# %%
# Import Libraries Required
import pandas as pd
import matplotlib as mp
import numpy as np
import matplotlib.pyplot as plt

filename = 'Dataset_of_Diabetes.csv'

data = pd.read_csv(filename, header=0)

# Display the data
data
# Out:
#       ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0    502      17975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 1    735      34221      M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 2    420      47975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 3    680      87656      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 4    504      34223      M   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4
# ..   ...        ...    ...  ...   ...  ..    ...   ...  ...  ...  ...   ...
# 995  200     454317      M   71  11.0  97    7.0   7.5  1.7  1.2  1.8   0.6
# 996  671     876534      M   31   3.0  60   12.3   4.1  2.2  0.7  2.4  15.4
# 997  669      87654      M   30   7.1  81    6.7   4.1  1.1  1.2  2.4   8.1
# 998   99      24004      M   38   5.8  59    6.7   5.3  2.0  1.6  2.9  14.0
# 999  248      24054      M   54   5.0  67    6.9   3.8  1.7  1.1  3.0   0.7
#
#       BMI CLASS
# 0    24.0     N
# 1    23.0     N
# ...

# %%
# see how big is the data
df = pd.DataFrame(data)
df.shape

print("There is ", df.shape[0] , " rows and ", df.shape[1], " columns")
# Out:
# There is  1000  rows and  14  columns

# %%
# show the columns title
df.columns
# Out:
# Index(['ID', 'No_Pation', 'Gender', 'AGE', 'Urea', 'Cr', 'HbA1c', 'Chol', 'TG',
#        'HDL', 'LDL', 'VLDL', 'BMI', 'CLASS'],
#       dtype='object')

# %% [markdown]
# Variable Description
#
# 1. ID is the identifier
# 2. No_Pation is the No of the patient
# 3. Gender is to show male or female
# 4. Age is the age of the patient
# 5. Urea is the urea molecule measured in mmol/l
# 6. Cr is the Creatinine ratio
# 7. HbA1c is the measure of the amount of blood sugar attached to the patient's  hemoglobin measured in mmol/L
# 8. Chol is the Cholesterol is measured in mmol/L
# 9. TG is Triglycerides is measured in mmol/L
# 10. HDL is high-density lipoprotein (good cholesterol) is measured in mmol/L
# 11. LDL is low-density lipoprotein is measured in mmol/L
# 12. VLDL is very low-density lipoprotein is measured in mmol/L
# 13. BMI is body mass index is measured in kg/m2
# 14. Diabetes disease class is to show do the patient has diabetes

# %%
# check is there any null value
df.isna().sum()
# Out:
# ID           0
# No_Pation    0
# Gender       0
# AGE          0
# Urea         0
# Cr           0
# HbA1c        0
# Chol         0
# TG           0
# HDL          0
# LDL          0
# VLDL         0
# BMI          0
# CLASS        0
# dtype: int64

# %% [markdown]
# Data Cleaning
#
# The data is clean have no null value as shown above. It is claen by Rashid Ahlam, Guan Lin Tao and kaki cuba.
#
# https://www.kaggle.com/aravindpcoder
# https://www.kaggle.com/guanlintao
# https://www.kaggle.com/kakicuba

# %% [markdown]
# These contributor have perform the data cleaning and fix, remove incorrect, corrupted, incorrected formatted, imcomplete data. However, there are still some typo in the data that missout by them.
#
# Below I change the columns name to imporve the Readbility of the data at the same time spell check all the columns name to make sure the spelling is correct. I have also found out that there is a typo in Diabeties Positive which the value have an extra space in it. I have also change certain type of data using 1 and 0 to represent. It is to make it convience to use in the future.

# %%
df.rename(columns={"ID": "ID" ,"No_Pation": "No_Patient", "Gender" : "Gender (M/F)", "AGE" : "Age", "Urea" : "Urea (mmol/l)", "Cr" : "Creatinine ratio", "HbA1c" : "HbA1c (mmol/L)", "Chol" : "Cholesterol (mmol/l)", "TG" : "Triglycerides (mmol/l)", "HDL" : "High-density lipoprotein (mmol/l)", "LDL": "Low Desity Lipoprotein (mmol/l)", "VLDL" : "Very Low Desity Liporpotein (mmol/l)", "BMI" : "Body Mass Index (kg/m²)", "CLASS" : "Diabeties Positive"} , inplace=True)

df['Diabeties Positive'].replace('Y ', 'Y', inplace=True)
df['Diabeties Positive'].replace('N ', 'N', inplace=True)

df['Diabeties Positive'].replace('N', 0, inplace=True)
df['Diabeties Positive'].replace('Y', 1, inplace=True)
df['Diabeties Positive'].replace('P', 1, inplace=True)

df
# Out:
#       ID  No_Patient Gender (M/F)  Age  Urea (mmol/l)  Creatinine ratio  \
# 0    502       17975            F   50            4.7                46
# 1    735       34221            M   26            4.5                62
# 2    420       47975            F   50            4.7                46
# 3    680       87656            F   50            4.7                46
# 4    504       34223            M   33            7.1                46
# ..   ...         ...          ...  ...            ...               ...
# 995  200      454317            M   71           11.0                97
# 996  671      876534            M   31            3.0                60
# 997  669       87654            M   30            7.1                81
# 998   99       24004            M   38            5.8                59
# 999  248       24054            M   54            5.0                67
#
#      HbA1c (mmol/L)  Cholesterol (mmol/l)  Triglycerides (mmol/l)  \
# ...

# %% [markdown]
# Support Vector Machine

# %%
from sklearn.model_selection import train_test_split  
from sklearn.preprocessing import StandardScaler 
from sklearn.svm import SVC 
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

X = df.iloc[:, 3:-1].values
y = df.iloc[:, -1].values

x_train, x_test, y_train, y_test= train_test_split(X, y, test_size= 0.25, random_state=0) 


st_x= StandardScaler()    
x_train= st_x.fit_transform(x_train)    
x_test= st_x.transform(x_test) 


# "Support vector classifier"  
classifier = SVC(kernel='linear', random_state=0)  
classifier.fit(x_train, y_train)  

y_pred= classifier.predict(x_test) 

cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)


plt.figure(figsize=(8, 6))

plt.scatter(x_test[y_test == 0, 0], x_test[y_test == 0, 1], color='blue', label='Actual Diabetise Negative: 0')

plt.scatter(x_test[y_test == 1, 0], x_test[y_test == 1, 1], color='orange', label='Actual Diabetise Positve: 1')

plt.scatter(x_test[y_pred == 0, 0], x_test[y_pred == 0, 1], color='green', marker='x', s=100, label='Predicted Diabetise Negative: 0')

plt.scatter(x_test[y_pred == 1, 0], x_test[y_pred == 1, 1], color='red', marker='x', s=100, label='Predicted Diabetise Positve: 1')

plt.title('Actual vs. Predicted')
plt.legend()
plt.show()
# Out:
# [[ 21   1]
#  [  4 224]]

# %% [markdown]
# As the result of confusion matrix shown above is [[21 , 1] [4 , 244]]. 21 is the true positive data and the model have incorrectly predict 1 data only for the true positive data. As for the true negative data it have 224 true negative data and the model have only incorrectly predict 4 data only. This have shown the accuracy for the SVC model.
#
# As the accuracy_sorce shown it have 0.98 accuracy. The Maximum of accuracy score is 1 and the result shown above is 0.98. This have shown the data have a great accuracy.

# %% [markdown]
# Decision Tree

# %%
X = df.iloc[:, 3:-1].values
y = df.iloc[:, -1].values

x_train, x_test, y_train, y_test= train_test_split(X, y, test_size= 0.25, random_state=0) 

decisiontree = DecisionTreeClassifier(random_state=42)

decisiontree.fit(x_train, y_train)

predictions = decisiontree.predict(x_test)

accuracy = accuracy_score(y_test, predictions)
print(accuracy)

print(classification_report(y_test, predictions))

plt.figure(figsize=(12, 8))
tree.plot_tree(decisiontree, feature_names=df.iloc[:, 3:-1].columns, class_names=['No Diabetes', 'Diabetes'], filled=True, rounded=True)
plt.show()
# Out:
# 0.996
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        22
#            1       1.00      1.00      1.00       228
#
#     accuracy                           1.00       250
#    macro avg       0.98      1.00      0.99       250
# weighted avg       1.00      1.00      1.00       250

# %% [markdown]
# On the above it for the decision tree it have shown that it have a 0.996 out of 1. Which is a great accuracy in decision tree. Moreover, In the decision tree graph it have show a greate accuracy as well. HbA1c, BMI, Cholesterol, Triglycerides, VLDL, Urea, LDL and Cholesterol have perfectely predict the patient which have or not have diabeties the value that in the decision tree have correctly shown as well. I have research on some of the value it have provent to be correct.
#
# https://www.breathewellbeing.in/blog/hba1c-a1c-chart-test-levels-normal-range/
# https://www.cdc.gov/healthyweight/assessing/index.html#:~:text=If%20your%20BMI%20is%20less,falls%20within%20the%20obese%20range.
# https://www.clevelandclinicabudhabi.ae/en/health-hub/health-resource/diseases-and-conditions/what-do-cholesterol-numbers-mean
# https://www.mayoclinic.org/diseases-conditions/high-blood-cholesterol/in-depth/triglycerides/art-20048186
# https://www.heartuk.org.uk/cholesterol/triglycerides
# https://www.mayoclinic.org/tests-procedures/blood-urea-nitrogen/about/pac-20384821#:~:text=In%20general%2C%20around%206%20to,doctor%20to%20explain%20your%20results.
# https://www.clevelandclinicabudhabi.ae/en/health-hub/health-resource/diseases-and-conditions/what-do-cholesterol-numbers-mean#:~:text=Your%20LDL%20cholesterol%20number%20is,130%2D159%20mg%2FdL
# https://www.uptodate.com/contents/high-cholesterol-and-lipids-beyond-the-basics/print#:~:text=A%20total%20cholesterol%20level%20of,mmol%2FL)%20is%20normal.&text=A%20total%20cholesterol%20level%20of%20200%20to%20239%20mg%2FdL,%2FL)%20is%20borderline%20high.&text=A%20total%20cholesterol%20level%20of%20240%20mg%2FdL%20(6.21%20mmol,measured%20any%20time%20of%20day.

# %% [markdown]
# Random Forest

# %%
X = df.iloc[:, 3:-1].values
y = df.iloc[:, -1].values

x_train, x_test, y_train, y_test= train_test_split(X, y, test_size= 0.25, random_state=0) 

randomtree = RandomForestClassifier(n_estimators=100, random_state=42)
randomtree.fit(x_train, y_train)

predictions = randomtree.predict(x_test)

accuracy = accuracy_score(y_test , predictions)
print(accuracy)

print(classification_report(y_test, predictions))
# Out:
# 0.996
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        22
#            1       1.00      1.00      1.00       228
#
#     accuracy                           1.00       250
#    macro avg       0.98      1.00      0.99       250
# weighted avg       1.00      1.00      1.00       250

# %% [markdown]
# Random Forest is a ensemble learning method as well. As you can see it have 0.996 accuracy as well as Decision Tree. The prediction have show that the data provided is as accurate as it is.

# %% [markdown]
# Look at some key information about the variables
#
# I have remove ID, No_Patient, and Gender as the result my be weird to read and I might be irelavant.
#
# Below is how the data described. As the result shown, the average people are in 53 year old and Age of 51 have contributed 25% of the data, Age of 55 have contributed 50% of the data and Age of 59 have contributed 75% of the data. The max age is 79 years old. For the BMI it have shown average of the people in this data is unhealty due to healty BMI is 18.5 to 24.9 and the mean value of BMI in this data is 29.57 which is an unhealthy BMI.

# %%
describetem = df.iloc[:, 3:]
describetem.describe()
# Out:
#                Age  Urea (mmol/l)  Creatinine ratio  HbA1c (mmol/L)  \
# count  1000.000000    1000.000000       1000.000000     1000.000000
# mean     53.528000       5.124743         68.943000        8.281160
# std       8.799241       2.935165         59.984747        2.534003
# min      20.000000       0.500000          6.000000        0.900000
# 25%      51.000000       3.700000         48.000000        6.500000
# 50%      55.000000       4.600000         60.000000        8.000000
# 75%      59.000000       5.700000         73.000000       10.200000
# max      79.000000      38.900000        800.000000       16.000000
#
#        Cholesterol (mmol/l)  Triglycerides (mmol/l)  \
# count           1000.000000             1000.000000
# mean               4.862820                2.349610
# std                1.301738                1.401176
# min                0.000000                0.300000
# 25%                4.000000                1.500000
# ...

# %% [markdown]
# HeatMap is to visualize the data using color and matrix. The brighter the color or higher the value, is to represent the common or higher activity; the darker the color or smaller the value is to represent the less activity or less common. Belown have shown a heatmap. As you can see, the Urea and Creatinine ratio have the highest or most common activity. Next, HbA1c have common activty with Diabeties positive. BMI also have a high relationship with Diabeties positive with just under 0.01 by HbA1c with Diabeties Positive.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your DataFrame with the data
correlation_matrix = df.iloc[:, 3:].corr()

# Create a heatmap
sns.heatmap(correlation_matrix, annot=True, cmap="RdYlGn", fmt=".2f")

# Display the plot
plt.show()

# %% [markdown]
# Let compare the BMI of diabeties postive and negative patient. As you can see below, the line graph have shown a singnificant differece in diabeties positive and negative patient. The blue represented the diabeties positive patients and the orange have represented the diabeties negative  patients. As result, healty patient my have a good body shape compare to other unhealty patients(diabeties positive).

# %%
# df['Body Mass Index (kg/m²)'].plot()
positivedata = df['Body Mass Index (kg/m²)'].loc[df['Diabeties Positive'] == 1]
negativedata = df['Body Mass Index (kg/m²)'].loc[df['Diabeties Positive'] == 0]

positivedata.plot()
negativedata.plot()

plt.xlabel('Patients')
plt.ylabel('Body Mass Index (kg/m²)')
# Out:
# Text(0, 0.5, 'Body Mass Index (kg/m²)')

# %% [markdown]
# HbA1c which have significant result as well. It it similar to BMI which diabeties negative patients have much lower HbA1c compare to the diabeties positive patients. The orange line represented the diabeties negative patient and the blue line represented the positive patients.

# %%
positivedata = df['HbA1c (mmol/L)'].loc[df['Diabeties Positive'] == 1]
negativedata = df['HbA1c (mmol/L)'].loc[df['Diabeties Positive'] == 0]

positivedata.plot()
negativedata.plot()

plt.ylabel('HbA1c (mmol/L)')
plt.xlabel('Patients')
# Out:
# Text(0.5, 0, 'Patients')

# %% [markdown]
# In heatmap have seen the most significate data that have relation which is Urea and Creatine. Hence, I have created a scatted plot to see the relationship between both. As you can see below, the scatterplot have shown tons of relationship between both of the data. Most of the data are gather around 0 to 7 (mmol/l) and under 100 creatine ratio. However, the scatter plot have shown most of the diabeties positive patients have exceeded 7.5 Urea (mmol/l). When comparing both of the data we can see that Urea is much more obvious comparing to Creatine Ratio. By this, we can know that Urea is a much more better approace when diagnose diabeties.

# %%
data = df[['Urea (mmol/l)', 'Creatinine ratio', 'Diabeties Positive']]

# Separate data based on the 'Diabeties Positive' values
diabetes_positive = data[data['Diabeties Positive'] == 1]
diabetes_negative = data[data['Diabeties Positive'] == 0]

# Scatter plot
plt.figure(figsize=(10, 5))
plt.scatter(diabetes_positive['Urea (mmol/l)'], diabetes_positive['Creatinine ratio'], label='Diabetes Positive', color='red')
plt.scatter(diabetes_negative['Urea (mmol/l)'], diabetes_negative['Creatinine ratio'], label='Diabetes Negative', color='blue')


plt.title('Scatter Plot of Urea vs Creatinine ratio by Diabetes Status')
plt.xlabel('Urea (mmol/l)')
plt.ylabel('Creatinine ratio')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()
